# %% [markdown]
# <a href="https://colab.research.google.com/github/daNizaparedesdenis-arch/ChallengeAluraStoreG9/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# De las 12 columnas entregadas con información solo 5 de estas nos sirven para el análisis solicitado. No se encuentran datos nulos en ninguna de las tiendas

# %% [markdown]
# #Manipulacion de datos

# %% [markdown]
# ##Eliminación de celdas no necesarias

# %%
tienda_depurada = tienda.drop(["Fecha de Compra", "Vendedor", "Lugar de Compra", "Método de pago", "Cantidad de cuotas"], axis=1)
tienda_depurada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Calificación            2359 non-null   int64
#  5   lat                     2359 non-null   float64
#  6   lon                     2359 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 129.1+ KB

# %%
tienda2_depurada = tienda2.drop(["Fecha de Compra", "Vendedor", "Lugar de Compra", "Método de pago", "Cantidad de cuotas"], axis=1)
tienda2_depurada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Calificación            2359 non-null   int64
#  5   lat                     2359 non-null   float64
#  6   lon                     2359 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 129.1+ KB

# %%
tienda3_depurada = tienda3.drop(["Fecha de Compra", "Vendedor", "Lugar de Compra", "Método de pago", "Cantidad de cuotas"], axis=1)
tienda3_depurada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Calificación            2359 non-null   int64
#  5   lat                     2359 non-null   float64
#  6   lon                     2359 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 129.1+ KB

# %%
tienda4_depurada = tienda4.drop(["Fecha de Compra", "Vendedor", "Lugar de Compra", "Método de pago", "Cantidad de cuotas"], axis=1)
tienda4_depurada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Calificación            2358 non-null   int64
#  5   lat                     2358 non-null   float64
#  6   lon                     2358 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 129.1+ KB

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ##Ingresos totales de cada tienda

# %%
ingresos_tienda = tienda_depurada["Precio"].sum()
print(ingresos_tienda)
# Out:
# 1150880400.0

# %%
ingresos_tienda2 = tienda2_depurada["Precio"].sum()
print(ingresos_tienda2)
# Out:
# 1116343500.0

# %%
ingresos_tienda3 = tienda3_depurada["Precio"].sum()
print(ingresos_tienda3)
# Out:
# 1098019600.0

# %%
ingresos_tienda4 = tienda4_depurada["Precio"].sum()
print(ingresos_tienda4)
# Out:
# 1038375700.0

# %% [markdown]
# En este análisis encontramos que la tienda con menores ingresos es la cuarta obteniendo ingresos de 1.038.375.700, en comparación con los mayores ingresos de la primera tienda que a obtenido ingresos por 1.150.880.400 .

# %% [markdown]
# # 2. Ventas por categoría

# %%
clasificación_tienda = tienda_depurada["Categoría del Producto"].value_counts()
print(clasificación_tienda)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
clasificación_tienda2 = tienda2_depurada["Categoría del Producto"].value_counts()
print(clasificación_tienda2)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
clasificación_tienda3 = tienda3_depurada["Categoría del Producto"].value_counts()
print(clasificación_tienda3)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
clasificación_tienda4 = tienda4_depurada["Categoría del Producto"].value_counts()
print(clasificación_tienda4)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# En este análisis nos encontramos que todas las tiendas presentan valores similares, siendo los 3 articulos más vendidos los Muebles, Electronicos y juguestes, mientras que el menos vendido es Articulos del hogar, salvo en la cuarta tienda en donde los menos vendido son los Instrumentos musicales.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
valoracion_media_tienda= tienda_depurada["Calificación"].mean()
print(valoracion_media_tienda)
# Out:
# 3.976685036032217

# %%
valoracion_media_tienda2= tienda2_depurada["Calificación"].mean()
print(valoracion_media_tienda2)
# Out:
# 4.037303942348453

# %%
valoracion_media_tienda3= tienda3_depurada["Calificación"].mean()
print(valoracion_media_tienda3)
# Out:
# 4.048325561678677

# %%
valoracion_media_tienda4= tienda4_depurada["Calificación"].mean()
print(valoracion_media_tienda4)
# Out:
# 3.9957591178965224

# %% [markdown]
# En el siguiente análisis nos encontramos con que la tienda con mejor promedio de calificaciones por parte de los clientes es la tienda 3, mientras que la que tiene el promedio más bajo es la tienda 1.

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_mas_vendido_tienda = tienda_depurada["Producto"].value_counts().head(1)
producto_menos_vendido_tienda = tienda_depurada["Producto"].value_counts().tail(1)
print(producto_mas_vendido_tienda)
print(producto_menos_vendido_tienda)
# Out:
# Producto
# Microondas    60
# Name: count, dtype: int64
# Producto
# Celular ABXY    33
# Name: count, dtype: int64

# %%
producto_mas_vendido_tienda2 = tienda2_depurada["Producto"].value_counts().head(1)
producto_menos_vendido_tienda2 = tienda2_depurada["Producto"].value_counts().tail(1)
print(producto_mas_vendido_tienda2)
print(producto_menos_vendido_tienda2)
# Out:
# Producto
# Iniciando en programación    65
# Name: count, dtype: int64
# Producto
# Juego de mesa    32
# Name: count, dtype: int64

# %%
producto_mas_vendido_tienda3 = tienda3_depurada["Producto"].value_counts().head(1)
producto_menos_vendido_tienda3 = tienda3_depurada["Producto"].value_counts().tail(1)
print(producto_mas_vendido_tienda3)
print(producto_menos_vendido_tienda3)
# Out:
# Producto
# Kit de bancas    57
# Name: count, dtype: int64
# Producto
# Bloques de construcción    35
# Name: count, dtype: int64

# %%
producto_mas_vendido_tienda4 = tienda4_depurada["Producto"].value_counts().head(1)
producto_menos_vendido_tienda4 = tienda4_depurada["Producto"].value_counts().tail(1)
print(producto_mas_vendido_tienda4)
print(producto_menos_vendido_tienda4)
# Out:
# Producto
# Cama box    62
# Name: count, dtype: int64
# Producto
# Guitarra eléctrica    33
# Name: count, dtype: int64

# %% [markdown]
# Segun los datos arrojados los articulos más vendidos son muy diferentes entre si: en la tienda 1 fueron microondas, en la tienda 2 fue un producto llamado "Iniciando con programación", en la tienda 3 fue un Kit de bancas y en la tienda 4 una cama box. En cambio, los productos menos vendidos fueron en la tienda 1 un celular ABXY, en la tienda 2 fueron juegos de mesa, en la tienda 3 fueron bloques de construccion y en la tienda 4 fueron guitarras electricas. Todo esto solo demuestra que cada tienda tiene tipos muy diferentes de clientes y con diferentes prioridades.

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_tienda = tienda_depurada["Costo de envío"].mean()
print(costo_envio_tienda)
# Out:
# 26018.60958033065

# %%
costo_envio_tienda2 = tienda2_depurada["Costo de envío"].mean()
print(costo_envio_tienda2)
# Out:
# 25216.235693090293

# %%
costo_envio_tienda3 = tienda3_depurada["Costo de envío"].mean()
print(costo_envio_tienda3)
# Out:
# 24805.680373039424

# %%
costo_envio_tienda4 = tienda4_depurada["Costo de envío"].mean()
print(costo_envio_tienda4)
# Out:
# 23459.457167090754

# %% [markdown]
# El valor promedio de envio por tienda son el mayor, el la tienda 1. Mientras que la tienda con menos costo de envio en promedio es la tienda 4

# %% [markdown]
# # Gráficos

# %% [markdown]
# ##Ingresos totales por tienda

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [
    ingresos_tienda,
    ingresos_tienda2,
    ingresos_tienda3,
    ingresos_tienda4
]

colores_pastel = ['#FADADD', '#D6EAF8', '#D5F5E3', '#FCF3CF']
explode = (0.03, 0.03, 0.03, 0.03)

plt.figure(figsize=(6, 6))

plt.pie(
    ingresos,
    labels=tiendas,
    colors=colores_pastel,
    explode=explode,
    autopct='%1.1f%%',
    startangle=90,
    shadow=True,
    wedgeprops={'edgecolor': 'gray'}
)

plt.title('Distribución porcentual de ingresos por tienda')
plt.axis('equal')

plt.show()

# %% [markdown]
# ##Ventas por Categoria

# %%
import matplotlib.pyplot as plt
clasificación_tienda.plot(kind="bar", color='#A9CCE3')
plt.title("Ventas por categoría - Tienda 1")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.xticks(rotation=45)
plt.show()

# %%
clasificación_tienda2.plot(kind="bar", color='#A9CCE3')
plt.title("Ventas por categoría - Tienda 2")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.xticks(rotation=45)
plt.show()

# %%
clasificación_tienda3.plot(kind="bar", color='#A9CCE3')
plt.title("Ventas por categoría - Tienda 3")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.xticks(rotation=45)
plt.show()

# %%
clasificación_tienda4.plot(kind="bar", color='#A9CCE3')
plt.title("Ventas por categoría - Tienda 4")
plt.xlabel("Categoría")
plt.ylabel("Cantidad vendida")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Clasificación promedio por tienda

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
valoraciones = [
    valoracion_media_tienda,
    valoracion_media_tienda2,
    valoracion_media_tienda3,
    valoracion_media_tienda4
]

colores_pastel = [
    '#FADADD',  # rosa pastel
    '#D6EAF8',  # azul pastel
    '#D5F5E3',  # verde pastel
    '#FCF3CF'   # amarillo pastel
]

explode = (0.03, 0.03, 0.03, 0.03)

plt.figure(figsize=(6, 6))

plt.pie(
    valoraciones,
    labels=tiendas,
    colors=colores_pastel,
    explode=explode,
    autopct='%1.1f%%',
    startangle=90,
    shadow=True,
    wedgeprops={'edgecolor': 'gray'}
)

plt.title('Distribución de la calificación promedio por tienda')
plt.axis('equal')

plt.show()

# %% [markdown]
# ##Productos más Vendidos

# %%
producto_mas_vendido_tienda = tienda_depurada["Producto"].value_counts().head(5)

plt.figure(figsize=(6,4))
plt.barh(producto_mas_vendido_tienda.index, producto_mas_vendido_tienda.values, height=0.5, color='#A9CCE3')
plt.title("Top 5 productos más vendidos - Tienda 1")
plt.xlabel("Cantidad vendida")
plt.ylabel("Producto")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Promedio de Costo de envio

# %% [markdown]
# # Informe final

# %% [markdown]
# # Extra: Análisis de desempeño geográfico

# %% [markdown]
# ###Gráfico

# %% [markdown]
# ###Explicación
